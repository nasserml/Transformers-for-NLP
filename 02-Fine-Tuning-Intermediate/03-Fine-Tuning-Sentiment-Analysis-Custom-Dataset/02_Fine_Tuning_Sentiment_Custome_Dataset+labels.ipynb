# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# File ‘AirlineTweets.csv’ already there; not retrieving.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import torch

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("AirlineTweets.csv")

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df[['airline_sentiment', 'text']].copy()

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df.airline_sentiment.hist()
# Out:
# <Axes: >

# %%
target_map = {'positive': 1, 'negative': 0, 'neutral': 2}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df2 = df[['text', 'target']]
df2.columns = ['sentence', 'label']
df2.to_csv('data.csv', index=None)

# %%
# !head data.csv
# Out:
# sentence,label
# @VirginAmerica What @dhepburn said.,2
# @VirginAmerica plus you've added commercials to the experience... tacky.,1
# @VirginAmerica I didn't today... Must mean I need to take another trip!,2
# "@VirginAmerica it's really aggressive to blast obnoxious ""entertainment"" in your guests' faces &amp; they have little recourse",0
# @VirginAmerica and it's a really big bad thing about it,0
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA",0
# "@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)",1
# "@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP",2

# %%
from datasets import load_dataset
raw_dataset = load_dataset('csv', data_files='data.csv')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=.3, seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
# if there are multinle csv files
# load_dataset('csv',  data_files=['file1.csv', 'file2.csv'])

# %%
# if there is already train test split
# load_dataset('csv',  data_files={
#                                   'train': ['file1.csv', 'file2.csv'],
#                                   'test': 'test.csv'
#                                  })

# %%
checkpoint = 'distilbert-base-cased'

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
def tokenize_fn(batch):
    return tokenizer(batch['sentence'], truncation=True)

# %%
tokenized_datasets = split.map(tokenize_fn, batched=True)
# Out:
# Map:   0%|          | 0/10248 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4392 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSequenceClassification, \
    AutoConfig, Trainer, TrainingArguments

# %%
config = AutoConfig.from_pretrained(checkpoint)

# %%
config
# Out:
# DistilBertConfig {
#   "_name_or_path": "distilbert-base-cased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.34.1",
#   "vocab_size": 28996
# }

# %%
config.id2label
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1'}

# %%
config.label2id
# Out:
# {'LABEL_0': 0, 'LABEL_1': 1}

# %%
config.id2label = {v:k for k,v in target_map.items()}
config.label2id = target_map

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    checkpoint, config=config)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'classifier.weight', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
# !pip install torch==1.13.1
# Out:
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (0.41.2)

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.34.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.13.1)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch!=1.12.0,>=1.10->transformers[torch]) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch!=1.12.0,>=1.10->transformers[torch]) (0.41.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.7.22)

# %%
# !pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.13.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (0.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)

# %%
training_args = TrainingArguments(
    output_dir='training_dir',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
    logits, labels = logits_and_labels
    predictions = np.argmax(logits, axis=-1)
    acc = np.mean(predictions==labels)
    f1 = f1_score(labels, predictions, average='macro')
    return {'accuracy': acc, 'f1': f1}

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1923' max='1923' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1923/1923 03:39, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.539100</td>
#       <td>0.420660</td>
#       <td>0.834699</td>
#       <td>0.776763</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.346000</td>
#       <td>0.484846</td>
#       <td>0.833561</td>
#       <td>0.771480</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.223800</td>
#       <td>0.646928</td>
#       <td>0.838342</td>
#       <td>0.785675</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1923, training_loss=0.32206626491378015, metrics={'train_runtime': 222.2506, 'train_samples_per_second': 138.33, 'train_steps_per_second': 8.652, 'total_flos': 387616869956304.0, 'train_loss': 0.32206626491378015, 'epoch': 3.0})

# %%
# !ls training_dir
# Out:
# checkpoint-1282  checkpoint-1923  checkpoint-641  runs

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-1282',
                      device=0)

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_pred = savedmodel(split['test']['sentence'])

# %%
test_pred
# Out:
# [{'label': 'positive', 'score': 0.9693740010261536},
#  {'label': 'positive', 'score': 0.9736958742141724},
#  {'label': 'positive', 'score': 0.9010999798774719},
#  {'label': 'positive', 'score': 0.9375857710838318},
#  {'label': 'neutral', 'score': 0.7082529067993164},
#  {'label': 'negative', 'score': 0.9966080188751221},
#  {'label': 'neutral', 'score': 0.764549195766449},
#  {'label': 'neutral', 'score': 0.7137510180473328},
#  {'label': 'positive', 'score': 0.9404456615447998},
#  {'label': 'negative', 'score': 0.9942637085914612},
#  {'label': 'negative', 'score': 0.9883934855461121},
#  {'label': 'negative', 'score': 0.995270311832428},
#  {'label': 'positive', 'score': 0.9474258422851562},
#  {'label': 'negative', 'score': 0.994462788105011},
#  {'label': 'neutral', 'score': 0.976239800453186},
#  {'label': 'neutral', 'score': 0.761513888835907},
#  {'label': 'negative', 'score': 0.6422183513641357},
#  {'label': 'negative', 'score': 0.9961852431297302},
#  {'label': 'negative', 'score': 0.9176755547523499},
#  {'label': 'negative', 'score': 0.9946734309196472},
#  {'label': 'neutral', 'score': 0.8173120617866516},
#  {'label': 'negative', 'score': 0.8337011337280273},
#  {'label': 'negative', 'score': 0.6938662528991699},
#  {'label': 'negative', 'score': 0.8951048851013184},
#  {'label': 'negative', 'score': 0.9961355924606323},
#  {'label': 'negative', 'score': 0.7975364327430725},
#  {'label': 'negative', 'score': 0.9965341091156006},
#  {'label': 'negative', 'score': 0.9960801005363464},
#  {'label': 'negative', 'score': 0.996601939201355},
#  {'label': 'negative', 'score': 0.9924232959747314},
#  {'label': 'negative', 'score': 0.9964900612831116},
#  {'label': 'positive', 'score': 0.7075934410095215},
#  {'label': 'negative', 'score': 0.9966928958892822},
#  {'label': 'negative', 'score': 0.9965835809707642},
#  {'label': 'positive', 'score': 0.9709588885307312},
#  {'label': 'negative', 'score': 0.9965969920158386},
#  {'label': 'positive', 'score': 0.7019887566566467},
#  {'label': 'negative', 'score': 0.9933745265007019},
#  {'label': 'negative', 'score': 0.9950740933418274},
#  {'label': 'neutral', 'score': 0.7984864711761475},
#  {'label': 'negative', 'score': 0.9952070116996765},
#  {'label': 'negative', 'score': 0.9891262054443359},
#  {'label': 'negative', 'score': 0.9954463839530945},
#  {'label': 'negative', 'score': 0.8528086543083191},
#  {'label': 'positive', 'score': 0.9433560967445374},
#  {'label': 'neutral', 'score': 0.5511211156845093},
#  {'label': 'negative', 'score': 0.989608108997345},
#  {'label': 'positive', 'score': 0.9531540870666504},
#  {'label': 'negative', 'score': 0.9953553676605225},
#  {'label': 'negative', 'score': 0.996788501739502},
#  {'label': 'negative', 'score': 0.9939489364624023},
#  {'label': 'negative', 'score': 0.979850709438324},
#  {'label': 'negative', 'score': 0.833688497543335},
#  {'label': 'negative', 'score': 0.9964595437049866},
#  {'label': 'negative', 'score': 0.9962338805198669},
#  {'label': 'negative', 'score': 0.996594250202179},
#  {'label': 'negative', 'score': 0.9638798832893372},
#  {'label': 'neutral', 'score': 0.9524353742599487},
#  {'label': 'negative', 'score': 0.9955638647079468},
#  {'label': 'positive', 'score': 0.9567818641662598},
#  {'label': 'negative', 'score': 0.9949404001235962},
#  {'label': 'negative', 'score': 0.9945257902145386},
#  {'label': 'negative', 'score': 0.994627058506012},
#  {'label': 'negative', 'score': 0.9955381751060486},
#  {'label': 'negative', 'score': 0.5530104637145996},
#  {'label': 'neutral', 'score': 0.9789572358131409},
#  {'label': 'negative', 'score': 0.992824912071228},
#  {'label': 'negative', 'score': 0.9956215023994446},
#  {'label': 'negative', 'score': 0.9964631199836731},
#  {'label': 'negative', 'score': 0.9504438638687134},
#  {'label': 'negative', 'score': 0.43471917510032654},
#  {'label': 'negative', 'score': 0.9709879755973816},
#  {'label': 'negative', 'score': 0.9693896770477295},
#  {'label': 'negative', 'score': 0.990971565246582},
#  {'label': 'negative', 'score': 0.5580872297286987},
#  {'label': 'negative', 'score': 0.9940453767776489},
#  {'label': 'negative', 'score': 0.9962270259857178},
#  {'label': 'negative', 'score': 0.9932231903076172},
#  {'label': 'negative', 'score': 0.9937440752983093},
#  {'label': 'negative', 'score': 0.9895768165588379},
#  {'label': 'negative', 'score': 0.9965116381645203},
#  {'label': 'positive', 'score': 0.519845187664032},
#  {'label': 'positive', 'score': 0.9694543480873108},
#  {'label': 'negative', 'score': 0.82442706823349},
#  {'label': 'positive', 'score': 0.9669529795646667},
#  {'label': 'neutral', 'score': 0.9457136988639832},
#  {'label': 'negative', 'score': 0.9961960315704346},
#  {'label': 'negative', 'score': 0.9423536658287048},
#  {'label': 'negative', 'score': 0.9950718283653259},
#  {'label': 'neutral', 'score': 0.5857879519462585},
#  {'label': 'negative', 'score': 0.9008535742759705},
#  {'label': 'negative', 'score': 0.9854359030723572},
#  {'label': 'negative', 'score': 0.9945634007453918},
#  {'label': 'positive', 'score': 0.48316341638565063},
#  {'label': 'negative', 'score': 0.9940932393074036},
#  {'label': 'negative', 'score': 0.9949329495429993},
#  {'label': 'negative', 'score': 0.9961049556732178},
#  {'label': 'negative', 'score': 0.9964861869812012},
#  {'label': 'negative', 'score': 0.9915930032730103},
#  {'label': 'negative', 'score': 0.995189905166626},
#  {'label': 'negative', 'score': 0.9965173006057739},
#  {'label': 'neutral', 'score': 0.9778954386711121},
#  {'label': 'neutral', 'score': 0.9207431077957153},
#  {'label': 'positive', 'score': 0.7190606594085693},
#  {'label': 'neutral', 'score': 0.4781384766101837},
#  {'label': 'negative', 'score': 0.9956691265106201},
#  {'label': 'negative', 'score': 0.815618634223938},
#  {'label': 'negative', 'score': 0.9950049519538879},
#  {'label': 'negative', 'score': 0.9942389726638794},
#  {'label': 'negative', 'score': 0.9960980415344238},
#  {'label': 'negative', 'score': 0.9941044449806213},
#  {'label': 'negative', 'score': 0.9959747195243835},
#  {'label': 'negative', 'score': 0.9854958653450012},
#  {'label': 'neutral', 'score': 0.6262006759643555},
#  {'label': 'negative', 'score': 0.9606655836105347},
#  {'label': 'neutral', 'score': 0.834991455078125},
#  {'label': 'negative', 'score': 0.9890994429588318},
#  {'label': 'positive', 'score': 0.5276437997817993},
#  {'label': 'negative', 'score': 0.9955278038978577},
#  {'label': 'negative', 'score': 0.7103763222694397},
#  {'label': 'neutral', 'score': 0.9613589644432068},
#  {'label': 'neutral', 'score': 0.5007531642913818},
#  {'label': 'neutral', 'score': 0.9517730474472046},
#  {'label': 'neutral', 'score': 0.9677245616912842},
#  {'label': 'negative', 'score': 0.9940071105957031},
#  {'label': 'negative', 'score': 0.9962269067764282},
#  {'label': 'negative', 'score': 0.985684871673584},
#  {'label': 'negative', 'score': 0.9965811371803284},
#  {'label': 'positive', 'score': 0.825692892074585},
#  {'label': 'negative', 'score': 0.9962994456291199},
#  {'label': 'positive', 'score': 0.9842049479484558},
#  {'label': 'negative', 'score': 0.9964355230331421},
#  {'label': 'negative', 'score': 0.9874271154403687},
#  {'label': 'positive', 'score': 0.9888567328453064},
#  {'label': 'neutral', 'score': 0.8781892657279968},
#  {'label': 'negative', 'score': 0.9172167778015137},
#  {'label': 'negative', 'score': 0.996173083782196},
#  {'label': 'negative', 'score': 0.9929908514022827},
#  {'label': 'negative', 'score': 0.9962124824523926},
#  {'label': 'negative', 'score': 0.9968084692955017},
#  {'label': 'negative', 'score': 0.9907392263412476},
#  {'label': 'negative', 'score': 0.9911233186721802},
#  {'label': 'negative', 'score': 0.9953827261924744},
#  {'label': 'negative', 'score': 0.9918877482414246},
#  {'label': 'neutral', 'score': 0.6680112481117249},
#  {'label': 'neutral', 'score': 0.5832920670509338},
#  {'label': 'neutral', 'score': 0.9431195259094238},
#  {'label': 'negative', 'score': 0.9965234398841858},
#  {'label': 'negative', 'score': 0.9959906935691833},
#  {'label': 'negative', 'score': 0.9967495203018188},
#  {'label': 'negative', 'score': 0.996260941028595},
#  {'label': 'neutral', 'score': 0.48371005058288574},
#  {'label': 'neutral', 'score': 0.9836046099662781},
#  {'label': 'neutral', 'score': 0.856685221195221},
#  {'label': 'positive', 'score': 0.9752905964851379},
#  {'label': 'neutral', 'score': 0.551463782787323},
#  {'label': 'negative', 'score': 0.9587574601173401},
#  {'label': 'negative', 'score': 0.9863104820251465},
#  {'label': 'negative', 'score': 0.9960134029388428},
#  {'label': 'negative', 'score': 0.9951789379119873},
#  {'label': 'negative', 'score': 0.7510750889778137},
#  {'label': 'negative', 'score': 0.9963805079460144},
#  {'label': 'positive', 'score': 0.5232817530632019},
#  {'label': 'negative', 'score': 0.9949199557304382},
#  {'label': 'negative', 'score': 0.9152551293373108},
#  {'label': 'negative', 'score': 0.944495439529419},
#  {'label': 'negative', 'score': 0.9962363839149475},
#  {'label': 'negative', 'score': 0.995934247970581},
#  {'label': 'neutral', 'score': 0.5756192803382874},
#  {'label': 'neutral', 'score': 0.9841756224632263},
#  {'label': 'negative', 'score': 0.9953961968421936},
#  {'label': 'negative', 'score': 0.9864253997802734},
#  {'label': 'negative', 'score': 0.807587206363678},
#  {'label': 'neutral', 'score': 0.8066317439079285},
#  {'label': 'positive', 'score': 0.8796972036361694},
#  {'label': 'positive', 'score': 0.6587538719177246},
#  {'label': 'negative', 'score': 0.9722859263420105},
#  {'label': 'negative', 'score': 0.9965403079986572},
#  {'label': 'negative', 'score': 0.9910810589790344},
#  {'label': 'negative', 'score': 0.9950166344642639},
#  {'label': 'negative', 'score': 0.9811006784439087},
#  {'label': 'positive', 'score': 0.6564791202545166},
#  {'label': 'negative', 'score': 0.9964411854743958},
#  {'label': 'negative', 'score': 0.9940663576126099},
#  {'label': 'negative', 'score': 0.9959482550621033},
#  {'label': 'neutral', 'score': 0.42588910460472107},
#  {'label': 'negative', 'score': 0.7519431114196777},
#  {'label': 'negative', 'score': 0.9947793483734131},
#  {'label': 'positive', 'score': 0.961341381072998},
#  {'label': 'negative', 'score': 0.9547610878944397},
#  {'label': 'negative', 'score': 0.9460867643356323},
#  {'label': 'negative', 'score': 0.9954534769058228},
#  {'label': 'negative', 'score': 0.9819748997688293},
#  {'label': 'negative', 'score': 0.8137781023979187},
#  {'label': 'negative', 'score': 0.9492999911308289},
#  {'label': 'neutral', 'score': 0.9274816513061523},
#  {'label': 'positive', 'score': 0.9817261099815369},
#  {'label': 'negative', 'score': 0.9602389335632324},
#  {'label': 'negative', 'score': 0.9958187937736511},
#  {'label': 'negative', 'score': 0.9935382008552551},
#  {'label': 'negative', 'score': 0.7344646453857422},
#  {'label': 'negative', 'score': 0.960167407989502},
#  {'label': 'negative', 'score': 0.849392831325531},
#  {'label': 'negative', 'score': 0.9959866404533386},
#  {'label': 'negative', 'score': 0.9953395128250122},
#  {'label': 'positive', 'score': 0.854886531829834},
#  {'label': 'neutral', 'score': 0.9800200462341309},
#  {'label': 'negative', 'score': 0.9965498447418213},
#  {'label': 'negative', 'score': 0.9960916638374329},
#  {'label': 'negative', 'score': 0.7663375735282898},
#  {'label': 'positive', 'score': 0.3577101528644562},
#  {'label': 'neutral', 'score': 0.9679350256919861},
#  {'label': 'positive', 'score': 0.9718158841133118},
#  {'label': 'negative', 'score': 0.9224514365196228},
#  {'label': 'negative', 'score': 0.9922367930412292},
#  {'label': 'neutral', 'score': 0.9856641292572021},
#  {'label': 'neutral', 'score': 0.9869005084037781},
#  {'label': 'negative', 'score': 0.9962000250816345},
#  {'label': 'neutral', 'score': 0.9472301006317139},
#  {'label': 'neutral', 'score': 0.7811145782470703},
#  {'label': 'negative', 'score': 0.9747691750526428},
#  {'label': 'negative', 'score': 0.9964882135391235},
#  {'label': 'negative', 'score': 0.9531717300415039},
#  {'label': 'neutral', 'score': 0.8620391488075256},
#  {'label': 'positive', 'score': 0.9711254835128784},
#  {'label': 'negative', 'score': 0.9857513308525085},
#  {'label': 'negative', 'score': 0.5826087594032288},
#  {'label': 'negative', 'score': 0.9950823783874512},
#  {'label': 'negative', 'score': 0.994196891784668},
#  {'label': 'negative', 'score': 0.9913508892059326},
#  {'label': 'negative', 'score': 0.5507181286811829},
#  {'label': 'negative', 'score': 0.9729388952255249},
#  {'label': 'negative', 'score': 0.9877961874008179},
#  {'label': 'negative', 'score': 0.9957140684127808},
#  {'label': 'negative', 'score': 0.9940586090087891},
#  {'label': 'positive', 'score': 0.9582912921905518},
#  {'label': 'negative', 'score': 0.9821546077728271},
#  {'label': 'negative', 'score': 0.9830994606018066},
#  {'label': 'negative', 'score': 0.9967079162597656},
#  {'label': 'negative', 'score': 0.7324509024620056},
#  {'label': 'negative', 'score': 0.9911709427833557},
#  {'label': 'neutral', 'score': 0.5341452360153198},
#  {'label': 'neutral', 'score': 0.5347968935966492},
#  {'label': 'negative', 'score': 0.7533230781555176},
#  {'label': 'negative', 'score': 0.9963173866271973},
#  {'label': 'negative', 'score': 0.9822354316711426},
#  {'label': 'negative', 'score': 0.9324706792831421},
#  {'label': 'negative', 'score': 0.7736665606498718},
#  {'label': 'negative', 'score': 0.5975334048271179},
#  {'label': 'neutral', 'score': 0.8553586006164551},
#  {'label': 'negative', 'score': 0.9960185885429382},
#  {'label': 'negative', 'score': 0.9912793040275574},
#  {'label': 'negative', 'score': 0.9961896538734436},
#  {'label': 'negative', 'score': 0.9964409470558167},
#  {'label': 'negative', 'score': 0.9946640729904175},
#  {'label': 'negative', 'score': 0.8945136070251465},
#  {'label': 'negative', 'score': 0.9811517596244812},
#  {'label': 'negative', 'score': 0.9965434670448303},
#  {'label': 'negative', 'score': 0.7551365494728088},
#  {'label': 'negative', 'score': 0.9200090765953064},
#  {'label': 'positive', 'score': 0.982333779335022},
#  {'label': 'negative', 'score': 0.9923563003540039},
#  {'label': 'negative', 'score': 0.9941680431365967},
#  {'label': 'positive', 'score': 0.9909549355506897},
#  {'label': 'positive', 'score': 0.9253571629524231},
#  {'label': 'negative', 'score': 0.9227292537689209},
#  {'label': 'negative', 'score': 0.9953492283821106},
#  {'label': 'negative', 'score': 0.9939396381378174},
#  {'label': 'positive', 'score': 0.8802283406257629},
#  {'label': 'positive', 'score': 0.9496115446090698},
#  {'label': 'negative', 'score': 0.9959490299224854},
#  {'label': 'negative', 'score': 0.9877212643623352},
#  {'label': 'negative', 'score': 0.5374237298965454},
#  {'label': 'negative', 'score': 0.986973762512207},
#  {'label': 'negative', 'score': 0.9901346564292908},
#  {'label': 'positive', 'score': 0.9662226438522339},
#  {'label': 'negative', 'score': 0.9960175156593323},
#  {'label': 'neutral', 'score': 0.496319055557251},
#  {'label': 'neutral', 'score': 0.9464239478111267},
#  {'label': 'negative', 'score': 0.9060938954353333},
#  {'label': 'negative', 'score': 0.9945012331008911},
#  {'label': 'negative', 'score': 0.9946179986000061},
#  {'label': 'neutral', 'score': 0.6391205191612244},
#  {'label': 'negative', 'score': 0.9936623573303223},
#  {'label': 'positive', 'score': 0.9746743440628052},
#  {'label': 'negative', 'score': 0.8194241523742676},
#  {'label': 'negative', 'score': 0.9942063093185425},
#  {'label': 'negative', 'score': 0.9966111779212952},
#  {'label': 'negative', 'score': 0.9946168065071106},
#  {'label': 'negative', 'score': 0.9966161847114563},
#  {'label': 'negative', 'score': 0.9911551475524902},
#  {'label': 'negative', 'score': 0.9961411356925964},
#  {'label': 'neutral', 'score': 0.9427165985107422},
#  {'label': 'positive', 'score': 0.5858967304229736},
#  {'label': 'negative', 'score': 0.9734185934066772},
#  {'label': 'negative', 'score': 0.9872439503669739},
#  {'label': 'neutral', 'score': 0.8955093622207642},
#  {'label': 'neutral', 'score': 0.9757109880447388},
#  {'label': 'negative', 'score': 0.9959750771522522},
#  {'label': 'negative', 'score': 0.9925393462181091},
#  {'label': 'negative', 'score': 0.9928174018859863},
#  {'label': 'neutral', 'score': 0.9695846438407898},
#  {'label': 'positive', 'score': 0.6387424468994141},
#  {'label': 'negative', 'score': 0.995303750038147},
#  {'label': 'neutral', 'score': 0.5286263823509216},
#  {'label': 'negative', 'score': 0.9870010614395142},
#  {'label': 'positive', 'score': 0.9357519149780273},
#  {'label': 'neutral', 'score': 0.8319819569587708},
#  {'label': 'neutral', 'score': 0.9357977509498596},
#  {'label': 'negative', 'score': 0.9957689046859741},
#  {'label': 'negative', 'score': 0.9882772564888},
#  {'label': 'negative', 'score': 0.9939047694206238},
#  {'label': 'negative', 'score': 0.9965803027153015},
#  {'label': 'neutral', 'score': 0.7392696738243103},
#  {'label': 'negative', 'score': 0.9962594509124756},
#  {'label': 'positive', 'score': 0.9585548639297485},
#  {'label': 'negative', 'score': 0.724547266960144},
#  {'label': 'neutral', 'score': 0.5779064297676086},
#  {'label': 'negative', 'score': 0.9675585627555847},
#  {'label': 'negative', 'score': 0.9929119944572449},
#  {'label': 'negative', 'score': 0.9964473843574524},
#  {'label': 'negative', 'score': 0.9274162650108337},
#  {'label': 'negative', 'score': 0.8830533027648926},
#  {'label': 'negative', 'score': 0.6410014033317566},
#  {'label': 'negative', 'score': 0.9893203973770142},
#  {'label': 'negative', 'score': 0.9948965907096863},
#  {'label': 'positive', 'score': 0.8494231104850769},
#  {'label': 'negative', 'score': 0.9801164865493774},
#  {'label': 'negative', 'score': 0.7169072031974792},
#  {'label': 'negative', 'score': 0.9704943895339966},
#  {'label': 'neutral', 'score': 0.9377663731575012},
#  {'label': 'negative', 'score': 0.9960826635360718},
#  {'label': 'negative', 'score': 0.9830621480941772},
#  {'label': 'positive', 'score': 0.9164955615997314},
#  {'label': 'negative', 'score': 0.9956074357032776},
#  {'label': 'negative', 'score': 0.9940003156661987},
#  {'label': 'negative', 'score': 0.5875020623207092},
#  {'label': 'negative', 'score': 0.9745116233825684},
#  {'label': 'neutral', 'score': 0.5468940734863281},
#  {'label': 'negative', 'score': 0.8476091623306274},
#  {'label': 'negative', 'score': 0.9816336035728455},
#  {'label': 'negative', 'score': 0.9951071739196777},
#  {'label': 'negative', 'score': 0.9954289197921753},
#  {'label': 'negative', 'score': 0.9937642812728882},
#  {'label': 'negative', 'score': 0.9935653805732727},
#  {'label': 'neutral', 'score': 0.8082121014595032},
#  {'label': 'negative', 'score': 0.9316705465316772},
#  {'label': 'negative', 'score': 0.9805431962013245},
#  {'label': 'negative', 'score': 0.9835078716278076},
#  {'label': 'positive', 'score': 0.9668967723846436},
#  {'label': 'neutral', 'score': 0.667475163936615},
#  {'label': 'positive', 'score': 0.9755584001541138},
#  {'label': 'positive', 'score': 0.9749857783317566},
#  {'label': 'negative', 'score': 0.9967495203018188},
#  {'label': 'neutral', 'score': 0.9822548627853394},
#  {'label': 'neutral', 'score': 0.6663760542869568},
#  {'label': 'negative', 'score': 0.9643717408180237},
#  {'label': 'positive', 'score': 0.9612528085708618},
#  {'label': 'positive', 'score': 0.46829575300216675},
#  {'label': 'negative', 'score': 0.9938141107559204},
#  {'label': 'negative', 'score': 0.9830604195594788},
#  {'label': 'negative', 'score': 0.9931469559669495},
#  {'label': 'negative', 'score': 0.9947693943977356},
#  {'label': 'negative', 'score': 0.9482436180114746},
#  {'label': 'positive', 'score': 0.5618106126785278},
#  {'label': 'negative', 'score': 0.9927964806556702},
#  {'label': 'negative', 'score': 0.9952705502510071},
#  {'label': 'positive', 'score': 0.9768930673599243},
#  {'label': 'negative', 'score': 0.9894134998321533},
#  {'label': 'negative', 'score': 0.9645515084266663},
#  {'label': 'positive', 'score': 0.5154606103897095},
#  {'label': 'negative', 'score': 0.9961798191070557},
#  {'label': 'positive', 'score': 0.9612092971801758},
#  {'label': 'negative', 'score': 0.9895273447036743},
#  {'label': 'positive', 'score': 0.9767464399337769},
#  {'label': 'negative', 'score': 0.9963825941085815},
#  {'label': 'neutral', 'score': 0.5899867415428162},
#  {'label': 'negative', 'score': 0.9914250373840332},
#  {'label': 'positive', 'score': 0.9798662066459656},
#  {'label': 'neutral', 'score': 0.975468099117279},
#  {'label': 'negative', 'score': 0.9966098666191101},
#  {'label': 'negative', 'score': 0.9945529103279114},
#  {'label': 'positive', 'score': 0.6963522434234619},
#  {'label': 'negative', 'score': 0.9929059743881226},
#  {'label': 'positive', 'score': 0.9884336590766907},
#  {'label': 'negative', 'score': 0.9899235367774963},
#  {'label': 'negative', 'score': 0.9964970946311951},
#  {'label': 'positive', 'score': 0.9768373370170593},
#  {'label': 'positive', 'score': 0.9860563278198242},
#  {'label': 'negative', 'score': 0.7588698267936707},
#  {'label': 'negative', 'score': 0.9955558180809021},
#  {'label': 'negative', 'score': 0.9964354038238525},
#  {'label': 'negative', 'score': 0.9793543815612793},
#  {'label': 'negative', 'score': 0.9922916293144226},
#  {'label': 'positive', 'score': 0.9732992053031921},
#  {'label': 'negative', 'score': 0.9840050935745239},
#  {'label': 'negative', 'score': 0.995105504989624},
#  {'label': 'positive', 'score': 0.9273926615715027},
#  {'label': 'negative', 'score': 0.9961366057395935},
#  {'label': 'negative', 'score': 0.9225113391876221},
#  {'label': 'positive', 'score': 0.5629539489746094},
#  {'label': 'positive', 'score': 0.879784345626831},
#  {'label': 'negative', 'score': 0.9944532513618469},
#  {'label': 'negative', 'score': 0.9787570834159851},
#  {'label': 'negative', 'score': 0.9943951368331909},
#  {'label': 'negative', 'score': 0.9961743354797363},
#  {'label': 'positive', 'score': 0.9637794494628906},
#  {'label': 'negative', 'score': 0.9955737590789795},
#  {'label': 'neutral', 'score': 0.9368139505386353},
#  {'label': 'negative', 'score': 0.995959460735321},
#  {'label': 'negative', 'score': 0.9913853406906128},
#  {'label': 'neutral', 'score': 0.5088686347007751},
#  {'label': 'negative', 'score': 0.9656451940536499},
#  {'label': 'negative', 'score': 0.9954565763473511},
#  {'label': 'negative', 'score': 0.989725649356842},
#  {'label': 'positive', 'score': 0.7304294109344482},
#  {'label': 'neutral', 'score': 0.938562273979187},
#  {'label': 'neutral', 'score': 0.7454493045806885},
#  {'label': 'neutral', 'score': 0.9777186512947083},
#  {'label': 'negative', 'score': 0.9915400147438049},
#  {'label': 'neutral', 'score': 0.9738962650299072},
#  {'label': 'negative', 'score': 0.7072197794914246},
#  {'label': 'negative', 'score': 0.9794872403144836},
#  {'label': 'positive', 'score': 0.9610857367515564},
#  {'label': 'negative', 'score': 0.9952386617660522},
#  {'label': 'negative', 'score': 0.9892472624778748},
#  {'label': 'negative', 'score': 0.9783768653869629},
#  {'label': 'negative', 'score': 0.9069058299064636},
#  {'label': 'negative', 'score': 0.9961983561515808},
#  {'label': 'negative', 'score': 0.968863844871521},
#  {'label': 'negative', 'score': 0.632564902305603},
#  {'label': 'negative', 'score': 0.9931921362876892},
#  {'label': 'positive', 'score': 0.9467906951904297},
#  {'label': 'negative', 'score': 0.8119471073150635},
#  {'label': 'neutral', 'score': 0.9457733035087585},
#  {'label': 'negative', 'score': 0.8189699649810791},
#  {'label': 'negative', 'score': 0.8171558380126953},
#  {'label': 'negative', 'score': 0.9956865906715393},
#  {'label': 'negative', 'score': 0.9486382603645325},
#  {'label': 'negative', 'score': 0.9956366419792175},
#  {'label': 'negative', 'score': 0.996632993221283},
#  {'label': 'positive', 'score': 0.897615373134613},
#  {'label': 'negative', 'score': 0.9852280616760254},
#  {'label': 'negative', 'score': 0.9946626424789429},
#  {'label': 'negative', 'score': 0.9963879585266113},
#  {'label': 'neutral', 'score': 0.6435033679008484},
#  {'label': 'negative', 'score': 0.9908616542816162},
#  {'label': 'negative', 'score': 0.9962220191955566},
#  {'label': 'negative', 'score': 0.788017749786377},
#  {'label': 'negative', 'score': 0.9940438866615295},
#  {'label': 'negative', 'score': 0.9959127306938171},
#  {'label': 'positive', 'score': 0.6102488040924072},
#  {'label': 'neutral', 'score': 0.8970421552658081},
#  {'label': 'negative', 'score': 0.991519033908844},
#  {'label': 'negative', 'score': 0.9941439032554626},
#  {'label': 'neutral', 'score': 0.5713614225387573},
#  {'label': 'negative', 'score': 0.9925601482391357},
#  {'label': 'positive', 'score': 0.9803736209869385},
#  {'label': 'negative', 'score': 0.857965886592865},
#  {'label': 'negative', 'score': 0.6509886384010315},
#  {'label': 'negative', 'score': 0.994729220867157},
#  {'label': 'negative', 'score': 0.9826194047927856},
#  {'label': 'negative', 'score': 0.8962935209274292},
#  {'label': 'negative', 'score': 0.9962148070335388},
#  {'label': 'negative', 'score': 0.9228576421737671},
#  {'label': 'neutral', 'score': 0.8952689170837402},
#  {'label': 'positive', 'score': 0.9634956121444702},
#  {'label': 'negative', 'score': 0.994712769985199},
#  {'label': 'positive', 'score': 0.9865853786468506},
#  {'label': 'negative', 'score': 0.5270769000053406},
#  {'label': 'neutral', 'score': 0.7548657655715942},
#  {'label': 'negative', 'score': 0.9089349508285522},
#  {'label': 'negative', 'score': 0.9963674545288086},
#  {'label': 'negative', 'score': 0.9372532963752747},
#  {'label': 'neutral', 'score': 0.9644970297813416},
#  {'label': 'negative', 'score': 0.9944579601287842},
#  {'label': 'negative', 'score': 0.8938408493995667},
#  {'label': 'negative', 'score': 0.9924668669700623},
#  {'label': 'positive', 'score': 0.9626495242118835},
#  {'label': 'neutral', 'score': 0.8656373620033264},
#  {'label': 'negative', 'score': 0.7395808100700378},
#  {'label': 'negative', 'score': 0.9944610595703125},
#  {'label': 'negative', 'score': 0.9954901337623596},
#  {'label': 'negative', 'score': 0.9477980732917786},
#  {'label': 'negative', 'score': 0.9959388971328735},
#  {'label': 'neutral', 'score': 0.8883187174797058},
#  {'label': 'neutral', 'score': 0.6937736868858337},
#  {'label': 'neutral', 'score': 0.9627482891082764},
#  {'label': 'negative', 'score': 0.9936429262161255},
#  {'label': 'negative', 'score': 0.9957183003425598},
#  {'label': 'negative', 'score': 0.9934343099594116},
#  {'label': 'negative', 'score': 0.6589940190315247},
#  {'label': 'neutral', 'score': 0.5218814015388489},
#  {'label': 'negative', 'score': 0.9964643716812134},
#  {'label': 'negative', 'score': 0.9886621832847595},
#  {'label': 'neutral', 'score': 0.7835289239883423},
#  {'label': 'neutral', 'score': 0.9554348587989807},
#  {'label': 'negative', 'score': 0.9916999936103821},
#  {'label': 'negative', 'score': 0.8959587216377258},
#  {'label': 'positive', 'score': 0.7212099432945251},
#  {'label': 'positive', 'score': 0.9571388363838196},
#  {'label': 'negative', 'score': 0.9858981370925903},
#  {'label': 'negative', 'score': 0.995243489742279},
#  {'label': 'negative', 'score': 0.9729892015457153},
#  {'label': 'negative', 'score': 0.9953910112380981},
#  {'label': 'positive', 'score': 0.9845114946365356},
#  {'label': 'negative', 'score': 0.9822762608528137},
#  {'label': 'negative', 'score': 0.9794396758079529},
#  {'label': 'negative', 'score': 0.9956412315368652},
#  {'label': 'negative', 'score': 0.9740158319473267},
#  {'label': 'negative', 'score': 0.99641352891922},
#  {'label': 'negative', 'score': 0.9777437448501587},
#  {'label': 'negative', 'score': 0.9811912178993225},
#  {'label': 'neutral', 'score': 0.9885978698730469},
#  {'label': 'negative', 'score': 0.9924365878105164},
#  {'label': 'negative', 'score': 0.9926338791847229},
#  {'label': 'negative', 'score': 0.9961483478546143},
#  {'label': 'negative', 'score': 0.9965235590934753},
#  {'label': 'neutral', 'score': 0.7236174941062927},
#  {'label': 'negative', 'score': 0.9962730407714844},
#  {'label': 'negative', 'score': 0.935824990272522},
#  {'label': 'negative', 'score': 0.9964983463287354},
#  {'label': 'neutral', 'score': 0.6004801392555237},
#  {'label': 'neutral', 'score': 0.9436182975769043},
#  {'label': 'neutral', 'score': 0.9604171514511108},
#  {'label': 'negative', 'score': 0.995631217956543},
#  {'label': 'negative', 'score': 0.9877430200576782},
#  {'label': 'positive', 'score': 0.9842737913131714},
#  {'label': 'negative', 'score': 0.9902430176734924},
#  {'label': 'negative', 'score': 0.9964863061904907},
#  {'label': 'negative', 'score': 0.9297776222229004},
#  {'label': 'neutral', 'score': 0.9448347687721252},
#  {'label': 'negative', 'score': 0.9947972893714905},
#  {'label': 'negative', 'score': 0.9961355924606323},
#  {'label': 'neutral', 'score': 0.7686046361923218},
#  {'label': 'negative', 'score': 0.9359991550445557},
#  {'label': 'neutral', 'score': 0.9424132704734802},
#  {'label': 'negative', 'score': 0.9912629127502441},
#  {'label': 'negative', 'score': 0.9709365367889404},
#  {'label': 'negative', 'score': 0.9890646934509277},
#  {'label': 'positive', 'score': 0.5074423551559448},
#  {'label': 'negative', 'score': 0.995961606502533},
#  {'label': 'neutral', 'score': 0.9213521480560303},
#  {'label': 'negative', 'score': 0.9963957667350769},
#  {'label': 'negative', 'score': 0.9830043315887451},
#  {'label': 'positive', 'score': 0.986951470375061},
#  {'label': 'negative', 'score': 0.9933371543884277},
#  {'label': 'positive', 'score': 0.9894469976425171},
#  {'label': 'neutral', 'score': 0.9433149099349976},
#  {'label': 'positive', 'score': 0.9821374416351318},
#  {'label': 'negative', 'score': 0.67664635181427},
#  {'label': 'negative', 'score': 0.994954526424408},
#  {'label': 'negative', 'score': 0.9662597179412842},
#  {'label': 'negative', 'score': 0.6714877486228943},
#  {'label': 'positive', 'score': 0.9616794586181641},
#  {'label': 'negative', 'score': 0.967434823513031},
#  {'label': 'negative', 'score': 0.9962027668952942},
#  {'label': 'negative', 'score': 0.9465566277503967},
#  {'label': 'positive', 'score': 0.9822900891304016},
#  {'label': 'neutral', 'score': 0.9774110913276672},
#  {'label': 'negative', 'score': 0.9957830905914307},
#  {'label': 'neutral', 'score': 0.9875490665435791},
#  {'label': 'negative', 'score': 0.5311058163642883},
#  {'label': 'positive', 'score': 0.9239090085029602},
#  {'label': 'negative', 'score': 0.9348708987236023},
#  {'label': 'negative', 'score': 0.996781587600708},
#  {'label': 'negative', 'score': 0.9954583644866943},
#  {'label': 'negative', 'score': 0.9318215250968933},
#  {'label': 'positive', 'score': 0.9577233791351318},
#  {'label': 'negative', 'score': 0.9959432482719421},
#  {'label': 'positive', 'score': 0.9299339652061462},
#  {'label': 'negative', 'score': 0.9964739680290222},
#  {'label': 'negative', 'score': 0.9963501691818237},
#  {'label': 'positive', 'score': 0.9846559762954712},
#  {'label': 'negative', 'score': 0.9860957264900208},
#  {'label': 'neutral', 'score': 0.9296756982803345},
#  {'label': 'negative', 'score': 0.9941148161888123},
#  {'label': 'negative', 'score': 0.4019175171852112},
#  {'label': 'neutral', 'score': 0.9670405983924866},
#  {'label': 'neutral', 'score': 0.8708825707435608},
#  {'label': 'negative', 'score': 0.9953195452690125},
#  {'label': 'negative', 'score': 0.9821668863296509},
#  {'label': 'negative', 'score': 0.5203878283500671},
#  {'label': 'negative', 'score': 0.9942916631698608},
#  {'label': 'negative', 'score': 0.995471715927124},
#  {'label': 'positive', 'score': 0.658318817615509},
#  {'label': 'negative', 'score': 0.98508620262146},
#  {'label': 'negative', 'score': 0.9226342439651489},
#  {'label': 'negative', 'score': 0.9888990521430969},
#  {'label': 'positive', 'score': 0.9722631573677063},
#  {'label': 'negative', 'score': 0.9935526847839355},
#  {'label': 'negative', 'score': 0.9964379072189331},
#  {'label': 'negative', 'score': 0.9959080219268799},
#  {'label': 'negative', 'score': 0.8790603876113892},
#  {'label': 'negative', 'score': 0.993206262588501},
#  {'label': 'negative', 'score': 0.9958939552307129},
#  {'label': 'negative', 'score': 0.9967515468597412},
#  {'label': 'negative', 'score': 0.9940943121910095},
#  {'label': 'negative', 'score': 0.9965127110481262},
#  {'label': 'negative', 'score': 0.9946893453598022},
#  {'label': 'neutral', 'score': 0.8875142335891724},
#  {'label': 'negative', 'score': 0.9934396147727966},
#  {'label': 'negative', 'score': 0.9893971681594849},
#  {'label': 'negative', 'score': 0.9932550191879272},
#  {'label': 'negative', 'score': 0.8502115607261658},
#  {'label': 'positive', 'score': 0.8207845091819763},
#  {'label': 'negative', 'score': 0.9882810711860657},
#  {'label': 'positive', 'score': 0.8212623000144958},
#  {'label': 'negative', 'score': 0.9930433034896851},
#  {'label': 'negative', 'score': 0.9954625964164734},
#  {'label': 'neutral', 'score': 0.7354571223258972},
#  {'label': 'negative', 'score': 0.9926645159721375},
#  {'label': 'neutral', 'score': 0.8840965032577515},
#  {'label': 'positive', 'score': 0.8894141316413879},
#  {'label': 'negative', 'score': 0.9640446901321411},
#  {'label': 'positive', 'score': 0.9295721650123596},
#  {'label': 'negative', 'score': 0.6002253890037537},
#  {'label': 'positive', 'score': 0.862769365310669},
#  {'label': 'negative', 'score': 0.9953696131706238},
#  {'label': 'negative', 'score': 0.9845817685127258},
#  {'label': 'negative', 'score': 0.9965329170227051},
#  {'label': 'positive', 'score': 0.9356018304824829},
#  {'label': 'negative', 'score': 0.9953612685203552},
#  {'label': 'neutral', 'score': 0.6181119084358215},
#  {'label': 'negative', 'score': 0.9940754175186157},
#  {'label': 'negative', 'score': 0.8820772767066956},
#  {'label': 'negative', 'score': 0.9857457876205444},
#  {'label': 'negative', 'score': 0.9960457682609558},
#  {'label': 'positive', 'score': 0.9865461587905884},
#  {'label': 'negative', 'score': 0.992809534072876},
#  {'label': 'neutral', 'score': 0.4295429289340973},
#  {'label': 'neutral', 'score': 0.9135176539421082},
#  {'label': 'negative', 'score': 0.9962440729141235},
#  {'label': 'negative', 'score': 0.9956766963005066},
#  {'label': 'negative', 'score': 0.7508991956710815},
#  {'label': 'negative', 'score': 0.9924517273902893},
#  {'label': 'negative', 'score': 0.995899498462677},
#  {'label': 'negative', 'score': 0.9956717491149902},
#  {'label': 'positive', 'score': 0.9871677756309509},
#  {'label': 'positive', 'score': 0.89910489320755},
#  {'label': 'negative', 'score': 0.9919546246528625},
#  {'label': 'negative', 'score': 0.9874561429023743},
#  {'label': 'negative', 'score': 0.9847191572189331},
#  {'label': 'negative', 'score': 0.9953433871269226},
#  {'label': 'negative', 'score': 0.9932286143302917},
#  {'label': 'negative', 'score': 0.9963087439537048},
#  {'label': 'positive', 'score': 0.973324179649353},
#  {'label': 'negative', 'score': 0.8283823728561401},
#  {'label': 'negative', 'score': 0.9916719794273376},
#  {'label': 'positive', 'score': 0.9880326986312866},
#  {'label': 'negative', 'score': 0.9038426876068115},
#  {'label': 'negative', 'score': 0.9786388278007507},
#  {'label': 'negative', 'score': 0.9958240985870361},
#  {'label': 'negative', 'score': 0.9507827758789062},
#  {'label': 'positive', 'score': 0.9293001890182495},
#  {'label': 'negative', 'score': 0.9943826198577881},
#  {'label': 'neutral', 'score': 0.8881703019142151},
#  {'label': 'negative', 'score': 0.9884541630744934},
#  {'label': 'negative', 'score': 0.9959192872047424},
#  {'label': 'positive', 'score': 0.9861976504325867},
#  {'label': 'positive', 'score': 0.9817821979522705},
#  {'label': 'negative', 'score': 0.9846346974372864},
#  {'label': 'negative', 'score': 0.9822115302085876},
#  {'label': 'negative', 'score': 0.994544506072998},
#  {'label': 'negative', 'score': 0.6884570717811584},
#  {'label': 'positive', 'score': 0.9424002170562744},
#  {'label': 'neutral', 'score': 0.933532178401947},
#  {'label': 'negative', 'score': 0.9956371188163757},
#  {'label': 'neutral', 'score': 0.9201915860176086},
#  {'label': 'negative', 'score': 0.883836567401886},
#  {'label': 'neutral', 'score': 0.8785017132759094},
#  {'label': 'negative', 'score': 0.9904064536094666},
#  {'label': 'negative', 'score': 0.9947283864021301},
#  {'label': 'negative', 'score': 0.9948580265045166},
#  {'label': 'negative', 'score': 0.9961714148521423},
#  {'label': 'negative', 'score': 0.99009108543396},
#  {'label': 'negative', 'score': 0.9940789937973022},
#  {'label': 'negative', 'score': 0.7568408846855164},
#  {'label': 'negative', 'score': 0.9956910014152527},
#  {'label': 'negative', 'score': 0.9954311847686768},
#  {'label': 'positive', 'score': 0.7262986898422241},
#  {'label': 'negative', 'score': 0.9891324639320374},
#  {'label': 'negative', 'score': 0.9965315461158752},
#  {'label': 'positive', 'score': 0.9548725485801697},
#  {'label': 'negative', 'score': 0.9878154993057251},
#  {'label': 'negative', 'score': 0.9774817824363708},
#  {'label': 'neutral', 'score': 0.4826279878616333},
#  {'label': 'positive', 'score': 0.975735068321228},
#  {'label': 'negative', 'score': 0.9964597821235657},
#  {'label': 'positive', 'score': 0.8501940369606018},
#  {'label': 'negative', 'score': 0.9961399435997009},
#  {'label': 'negative', 'score': 0.995033860206604},
#  {'label': 'negative', 'score': 0.9951820969581604},
#  {'label': 'negative', 'score': 0.9962812066078186},
#  {'label': 'negative', 'score': 0.9505105018615723},
#  {'label': 'neutral', 'score': 0.9858346581459045},
#  {'label': 'positive', 'score': 0.9605363607406616},
#  {'label': 'positive', 'score': 0.9115626811981201},
#  {'label': 'negative', 'score': 0.966832160949707},
#  {'label': 'negative', 'score': 0.9938644766807556},
#  {'label': 'negative', 'score': 0.615450918674469},
#  {'label': 'neutral', 'score': 0.9682835340499878},
#  {'label': 'negative', 'score': 0.9607241153717041},
#  {'label': 'neutral', 'score': 0.9643313884735107},
#  {'label': 'positive', 'score': 0.7797451019287109},
#  {'label': 'neutral', 'score': 0.9615746736526489},
#  {'label': 'negative', 'score': 0.995152473449707},
#  {'label': 'negative', 'score': 0.9922423362731934},
#  {'label': 'negative', 'score': 0.995536208152771},
#  {'label': 'negative', 'score': 0.9940903782844543},
#  {'label': 'neutral', 'score': 0.5178351402282715},
#  {'label': 'negative', 'score': 0.9933664202690125},
#  {'label': 'negative', 'score': 0.6575210094451904},
#  {'label': 'positive', 'score': 0.759139895439148},
#  {'label': 'positive', 'score': 0.9542953372001648},
#  {'label': 'negative', 'score': 0.996187150478363},
#  {'label': 'negative', 'score': 0.9956203103065491},
#  {'label': 'neutral', 'score': 0.6901714205741882},
#  {'label': 'negative', 'score': 0.8620101809501648},
#  {'label': 'neutral', 'score': 0.9871872663497925},
#  {'label': 'negative', 'score': 0.9959164261817932},
#  {'label': 'negative', 'score': 0.990670919418335},
#  {'label': 'negative', 'score': 0.9944251775741577},
#  {'label': 'negative', 'score': 0.9941719174385071},
#  {'label': 'negative', 'score': 0.9965935349464417},
#  {'label': 'negative', 'score': 0.7951321601867676},
#  {'label': 'negative', 'score': 0.9934779405593872},
#  {'label': 'negative', 'score': 0.8115606307983398},
#  {'label': 'positive', 'score': 0.9774032235145569},
#  {'label': 'negative', 'score': 0.9909793138504028},
#  {'label': 'negative', 'score': 0.9948145747184753},
#  {'label': 'negative', 'score': 0.9927113056182861},
#  {'label': 'negative', 'score': 0.996290922164917},
#  {'label': 'neutral', 'score': 0.8860817551612854},
#  {'label': 'positive', 'score': 0.9869151711463928},
#  {'label': 'negative', 'score': 0.7462076544761658},
#  {'label': 'positive', 'score': 0.9717151522636414},
#  {'label': 'negative', 'score': 0.9929789900779724},
#  {'label': 'negative', 'score': 0.9962816834449768},
#  {'label': 'positive', 'score': 0.4858199954032898},
#  {'label': 'negative', 'score': 0.9786190390586853},
#  {'label': 'negative', 'score': 0.9958005547523499},
#  {'label': 'positive', 'score': 0.982727587223053},
#  {'label': 'negative', 'score': 0.9877986311912537},
#  {'label': 'negative', 'score': 0.9958702921867371},
#  {'label': 'negative', 'score': 0.9702023267745972},
#  {'label': 'positive', 'score': 0.7840180397033691},
#  {'label': 'negative', 'score': 0.9942765831947327},
#  {'label': 'negative', 'score': 0.9969460368156433},
#  {'label': 'neutral', 'score': 0.834324836730957},
#  {'label': 'positive', 'score': 0.9808463454246521},
#  {'label': 'negative', 'score': 0.9921166300773621},
#  {'label': 'negative', 'score': 0.9849206805229187},
#  {'label': 'negative', 'score': 0.95864337682724},
#  {'label': 'neutral', 'score': 0.786927342414856},
#  {'label': 'negative', 'score': 0.9926884770393372},
#  {'label': 'negative', 'score': 0.9253018498420715},
#  {'label': 'negative', 'score': 0.9919811487197876},
#  {'label': 'negative', 'score': 0.9959361553192139},
#  {'label': 'neutral', 'score': 0.3976954221725464},
#  {'label': 'positive', 'score': 0.9786084294319153},
#  {'label': 'neutral', 'score': 0.97982257604599},
#  {'label': 'negative', 'score': 0.9948910474777222},
#  {'label': 'negative', 'score': 0.996337890625},
#  {'label': 'neutral', 'score': 0.7938136458396912},
#  {'label': 'negative', 'score': 0.9953082203865051},
#  {'label': 'negative', 'score': 0.9954330921173096},
#  {'label': 'negative', 'score': 0.9946234226226807},
#  {'label': 'positive', 'score': 0.8000721335411072},
#  {'label': 'negative', 'score': 0.7773064970970154},
#  {'label': 'neutral', 'score': 0.7630999088287354},
#  {'label': 'negative', 'score': 0.995360791683197},
#  {'label': 'neutral', 'score': 0.8803340196609497},
#  {'label': 'positive', 'score': 0.6624492406845093},
#  {'label': 'negative', 'score': 0.9677127003669739},
#  {'label': 'negative', 'score': 0.9963623881340027},
#  {'label': 'negative', 'score': 0.9966662526130676},
#  {'label': 'negative', 'score': 0.9968197345733643},
#  {'label': 'negative', 'score': 0.6643097996711731},
#  {'label': 'positive', 'score': 0.5085787177085876},
#  {'label': 'negative', 'score': 0.994629442691803},
#  {'label': 'negative', 'score': 0.9833106994628906},
#  {'label': 'negative', 'score': 0.9805010557174683},
#  {'label': 'negative', 'score': 0.6542292833328247},
#  {'label': 'negative', 'score': 0.9738227128982544},
#  {'label': 'neutral', 'score': 0.8691325187683105},
#  {'label': 'negative', 'score': 0.9962880611419678},
#  {'label': 'neutral', 'score': 0.437780499458313},
#  {'label': 'negative', 'score': 0.9937013387680054},
#  {'label': 'negative', 'score': 0.9917353987693787},
#  {'label': 'negative', 'score': 0.9855297207832336},
#  {'label': 'positive', 'score': 0.9795780777931213},
#  {'label': 'negative', 'score': 0.9749040603637695},
#  {'label': 'negative', 'score': 0.9024675488471985},
#  {'label': 'positive', 'score': 0.9844531416893005},
#  {'label': 'neutral', 'score': 0.9601175785064697},
#  {'label': 'negative', 'score': 0.9936605095863342},
#  {'label': 'negative', 'score': 0.996453046798706},
#  {'label': 'positive', 'score': 0.7832387685775757},
#  {'label': 'negative', 'score': 0.9954889416694641},
#  {'label': 'negative', 'score': 0.9938791990280151},
#  {'label': 'negative', 'score': 0.9936663508415222},
#  {'label': 'negative', 'score': 0.9910736680030823},
#  {'label': 'negative', 'score': 0.9955463409423828},
#  {'label': 'negative', 'score': 0.9959017634391785},
#  {'label': 'neutral', 'score': 0.5830696821212769},
#  {'label': 'negative', 'score': 0.6152138113975525},
#  {'label': 'neutral', 'score': 0.9683856964111328},
#  {'label': 'negative', 'score': 0.9952583909034729},
#  {'label': 'neutral', 'score': 0.4764036536216736},
#  {'label': 'negative', 'score': 0.9963706731796265},
#  {'label': 'negative', 'score': 0.9890916347503662},
#  {'label': 'negative', 'score': 0.9960969090461731},
#  {'label': 'negative', 'score': 0.993889331817627},
#  {'label': 'negative', 'score': 0.5078145861625671},
#  {'label': 'negative', 'score': 0.9953039884567261},
#  {'label': 'negative', 'score': 0.9935213923454285},
#  {'label': 'neutral', 'score': 0.7817142009735107},
#  {'label': 'neutral', 'score': 0.8781909346580505},
#  {'label': 'neutral', 'score': 0.9314348101615906},
#  {'label': 'positive', 'score': 0.9647319912910461},
#  {'label': 'negative', 'score': 0.8294842839241028},
#  {'label': 'positive', 'score': 0.9806985259056091},
#  {'label': 'positive', 'score': 0.9627441167831421},
#  {'label': 'positive', 'score': 0.8160548210144043},
#  {'label': 'negative', 'score': 0.7142233848571777},
#  {'label': 'negative', 'score': 0.7045742273330688},
#  {'label': 'negative', 'score': 0.9966508746147156},
#  {'label': 'negative', 'score': 0.9952366352081299},
#  {'label': 'negative', 'score': 0.9968101382255554},
#  {'label': 'positive', 'score': 0.9473057985305786},
#  {'label': 'positive', 'score': 0.98385089635849},
#  {'label': 'negative', 'score': 0.9960426092147827},
#  {'label': 'negative', 'score': 0.9637963771820068},
#  {'label': 'negative', 'score': 0.9937765598297119},
#  {'label': 'negative', 'score': 0.9939197301864624},
#  {'label': 'neutral', 'score': 0.8212819695472717},
#  {'label': 'positive', 'score': 0.9626928567886353},
#  {'label': 'negative', 'score': 0.982736349105835},
#  {'label': 'negative', 'score': 0.9881454706192017},
#  {'label': 'negative', 'score': 0.9845684766769409},
#  {'label': 'negative', 'score': 0.9966121315956116},
#  {'label': 'negative', 'score': 0.8973239660263062},
#  {'label': 'negative', 'score': 0.9808217883110046},
#  {'label': 'negative', 'score': 0.9897170066833496},
#  {'label': 'negative', 'score': 0.9951019287109375},
#  {'label': 'positive', 'score': 0.9841947555541992},
#  {'label': 'positive', 'score': 0.870715320110321},
#  {'label': 'negative', 'score': 0.9962175488471985},
#  {'label': 'positive', 'score': 0.5518092513084412},
#  {'label': 'negative', 'score': 0.9077802896499634},
#  {'label': 'negative', 'score': 0.9949069619178772},
#  {'label': 'positive', 'score': 0.891714334487915},
#  {'label': 'negative', 'score': 0.8905688524246216},
#  {'label': 'negative', 'score': 0.9963324666023254},
#  {'label': 'negative', 'score': 0.9012237787246704},
#  {'label': 'negative', 'score': 0.9910489320755005},
#  {'label': 'negative', 'score': 0.8791244626045227},
#  {'label': 'negative', 'score': 0.9955400824546814},
#  {'label': 'positive', 'score': 0.9511961936950684},
#  {'label': 'negative', 'score': 0.9919037222862244},
#  {'label': 'negative', 'score': 0.9942626357078552},
#  {'label': 'negative', 'score': 0.9902821779251099},
#  {'label': 'positive', 'score': 0.9225413203239441},
#  {'label': 'negative', 'score': 0.9903226494789124},
#  {'label': 'negative', 'score': 0.9924203753471375},
#  {'label': 'positive', 'score': 0.3577101528644562},
#  {'label': 'negative', 'score': 0.9359455108642578},
#  {'label': 'negative', 'score': 0.9840699434280396},
#  {'label': 'neutral', 'score': 0.9836214780807495},
#  {'label': 'neutral', 'score': 0.9598676562309265},
#  {'label': 'negative', 'score': 0.9944960474967957},
#  {'label': 'negative', 'score': 0.9761078953742981},
#  {'label': 'negative', 'score': 0.9443365931510925},
#  {'label': 'positive', 'score': 0.9902771711349487},
#  {'label': 'negative', 'score': 0.8460180163383484},
#  {'label': 'negative', 'score': 0.9901242852210999},
#  {'label': 'positive', 'score': 0.8933061361312866},
#  {'label': 'negative', 'score': 0.9927793145179749},
#  {'label': 'negative', 'score': 0.9960136413574219},
#  {'label': 'negative', 'score': 0.9948927164077759},
#  {'label': 'negative', 'score': 0.9964220523834229},
#  {'label': 'positive', 'score': 0.756045937538147},
#  {'label': 'negative', 'score': 0.992592990398407},
#  {'label': 'negative', 'score': 0.994253933429718},
#  {'label': 'positive', 'score': 0.9849100708961487},
#  {'label': 'negative', 'score': 0.9961052536964417},
#  {'label': 'positive', 'score': 0.6962329745292664},
#  {'label': 'negative', 'score': 0.9905078411102295},
#  {'label': 'negative', 'score': 0.9767556190490723},
#  {'label': 'negative', 'score': 0.7872567772865295},
#  {'label': 'positive', 'score': 0.9842435121536255},
#  {'label': 'neutral', 'score': 0.9816261529922485},
#  {'label': 'negative', 'score': 0.5353267192840576},
#  {'label': 'neutral', 'score': 0.6299843192100525},
#  {'label': 'neutral', 'score': 0.6773175597190857},
#  {'label': 'positive', 'score': 0.9652730822563171},
#  {'label': 'negative', 'score': 0.9965137839317322},
#  {'label': 'neutral', 'score': 0.6534333825111389},
#  {'label': 'neutral', 'score': 0.9595192074775696},
#  {'label': 'negative', 'score': 0.9860174059867859},
#  {'label': 'negative', 'score': 0.7105773091316223},
#  {'label': 'negative', 'score': 0.9953363537788391},
#  {'label': 'negative', 'score': 0.5837023854255676},
#  {'label': 'negative', 'score': 0.9957489967346191},
#  {'label': 'neutral', 'score': 0.5945584177970886},
#  {'label': 'positive', 'score': 0.9631959199905396},
#  {'label': 'negative', 'score': 0.9949893355369568},
#  {'label': 'negative', 'score': 0.9763867259025574},
#  {'label': 'negative', 'score': 0.9921581745147705},
#  {'label': 'negative', 'score': 0.996436357498169},
#  {'label': 'neutral', 'score': 0.9861193895339966},
#  {'label': 'neutral', 'score': 0.83709317445755},
#  {'label': 'negative', 'score': 0.9920406937599182},
#  {'label': 'negative', 'score': 0.9923253059387207},
#  {'label': 'negative', 'score': 0.9947159886360168},
#  {'label': 'negative', 'score': 0.9928245544433594},
#  {'label': 'positive', 'score': 0.9848712086677551},
#  {'label': 'positive', 'score': 0.9406419396400452},
#  {'label': 'negative', 'score': 0.9936564564704895},
#  {'label': 'positive', 'score': 0.8549022674560547},
#  {'label': 'neutral', 'score': 0.9761917591094971},
#  {'label': 'negative', 'score': 0.9488602876663208},
#  {'label': 'negative', 'score': 0.9966561794281006},
#  {'label': 'negative', 'score': 0.9914969801902771},
#  {'label': 'neutral', 'score': 0.5527900457382202},
#  {'label': 'positive', 'score': 0.9738208651542664},
#  {'label': 'negative', 'score': 0.9956389665603638},
#  {'label': 'negative', 'score': 0.9958273768424988},
#  {'label': 'negative', 'score': 0.9956626296043396},
#  {'label': 'positive', 'score': 0.9866644144058228},
#  {'label': 'neutral', 'score': 0.6936356425285339},
#  {'label': 'negative', 'score': 0.9964358806610107},
#  {'label': 'negative', 'score': 0.9862804412841797},
#  {'label': 'negative', 'score': 0.9956772923469543},
#  {'label': 'negative', 'score': 0.9963086247444153},
#  {'label': 'negative', 'score': 0.9942223429679871},
#  {'label': 'negative', 'score': 0.9836685061454773},
#  {'label': 'neutral', 'score': 0.971858024597168},
#  {'label': 'positive', 'score': 0.9801807999610901},
#  {'label': 'negative', 'score': 0.9841311573982239},
#  {'label': 'negative', 'score': 0.9756852388381958},
#  {'label': 'negative', 'score': 0.9917812943458557},
#  {'label': 'negative', 'score': 0.9844776391983032},
#  {'label': 'neutral', 'score': 0.9824275374412537},
#  {'label': 'negative', 'score': 0.9804421067237854},
#  {'label': 'positive', 'score': 0.9687401652336121},
#  {'label': 'negative', 'score': 0.9930511713027954},
#  {'label': 'negative', 'score': 0.9699440002441406},
#  {'label': 'positive', 'score': 0.9191693663597107},
#  {'label': 'negative', 'score': 0.9965135455131531},
#  {'label': 'positive', 'score': 0.9788259863853455},
#  {'label': 'negative', 'score': 0.996096670627594},
#  {'label': 'negative', 'score': 0.9959405660629272},
#  {'label': 'negative', 'score': 0.9965918064117432},
#  {'label': 'negative', 'score': 0.9960538148880005},
#  {'label': 'negative', 'score': 0.8147638440132141},
#  {'label': 'positive', 'score': 0.9889391660690308},
#  {'label': 'neutral', 'score': 0.9565107822418213},
#  {'label': 'negative', 'score': 0.9933939576148987},
#  {'label': 'negative', 'score': 0.9716216325759888},
#  {'label': 'negative', 'score': 0.9954527020454407},
#  {'label': 'negative', 'score': 0.8472424745559692},
#  {'label': 'negative', 'score': 0.992284893989563},
#  {'label': 'negative', 'score': 0.9960697889328003},
#  {'label': 'negative', 'score': 0.9962855577468872},
#  {'label': 'negative', 'score': 0.9835004806518555},
#  {'label': 'negative', 'score': 0.9941089153289795},
#  {'label': 'neutral', 'score': 0.9861711859703064},
#  {'label': 'positive', 'score': 0.8549779057502747},
#  {'label': 'negative', 'score': 0.9920235872268677},
#  {'label': 'positive', 'score': 0.7967771291732788},
#  {'label': 'negative', 'score': 0.9502336978912354},
#  {'label': 'negative', 'score': 0.9729267954826355},
#  {'label': 'positive', 'score': 0.8350410461425781},
#  {'label': 'negative', 'score': 0.9956503510475159},
#  {'label': 'negative', 'score': 0.9944636225700378},
#  {'label': 'negative', 'score': 0.9765595197677612},
#  {'label': 'positive', 'score': 0.975371778011322},
#  {'label': 'negative', 'score': 0.9876106977462769},
#  {'label': 'negative', 'score': 0.9963443875312805},
#  {'label': 'negative', 'score': 0.9956678152084351},
#  {'label': 'positive', 'score': 0.8813663721084595},
#  {'label': 'negative', 'score': 0.9735426306724548},
#  {'label': 'positive', 'score': 0.9830442070960999},
#  {'label': 'negative', 'score': 0.995406985282898},
#  {'label': 'negative', 'score': 0.9627909660339355},
#  {'label': 'negative', 'score': 0.9956614375114441},
#  {'label': 'neutral', 'score': 0.9836671352386475},
#  {'label': 'negative', 'score': 0.9951016306877136},
#  {'label': 'negative', 'score': 0.9958133101463318},
#  {'label': 'negative', 'score': 0.804166853427887},
#  {'label': 'negative', 'score': 0.9944896697998047},
#  {'label': 'negative', 'score': 0.9887946844100952},
#  {'label': 'negative', 'score': 0.9955790638923645},
#  {'label': 'positive', 'score': 0.9857599139213562},
#  {'label': 'negative', 'score': 0.996529757976532},
#  {'label': 'negative', 'score': 0.9853142499923706},
#  {'label': 'negative', 'score': 0.974677562713623},
#  {'label': 'negative', 'score': 0.6557022929191589},
#  ...]
